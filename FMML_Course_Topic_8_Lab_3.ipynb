# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhanuprasadh/FMML-Assignment-Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-02 17:19:19--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   131MB/s    in 0.5s
#
# 2023-05-02 17:19:20 (131 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11196   1412.7477v7  The pathwise coordinate optimization is one of...  stat
# 14699   1006.5880v1  The Right Frontier Constraint (RFC), as a cons...    cs
# 27283  1703.01290v1  Weakly-supervised object detection (WOD) is a ...    cs
# 699     1406.3793v1  Faces are a class of visual stimuli with uniqu...    cs
# 4456   1712.00996v1  Machine learning approaches hold great potenti...  stat
# ...             ...                                                ...   ...
# 33667  1507.07403v1  Open-ended evolutionary dynamics remains an el...    cs
# 23656   0906.3770v1  Quality control is an important issue in the c...    cs
# 34214   1404.1982v1  Text is the main method of communicating infor...    cs
# 21818   1202.2476v1  High-dimensional tensors or multi-way data are...  stat
# 7774   1803.02922v2  Modern supervised learning techniques, particu...  stat
#
#                                                    title  year  \
# 11196  Pathwise Coordinate Optimization for Sparse Le...  2014
# 14699                      Testing SDRT's Right Frontier  2010
# 27283  Bridging Saliency Detection to Weakly Supervis...  2017
# 699    Neural tuning size is a key factor underlying ...  2014
# 4456   Learning to detect chest radiographs containin...  2017
# ...                                                  ...   ...
# 33667  Requirements for Open-Ended Evolution in Natur...  2015
# 23656  Automatic Defect Detection and Classification ...  2009
# 34214  Aspect-Based Opinion Extraction from Customer ...  2014
# 21818  Regularized Tensor Factorizations and Higher-O...  2012
# 7774   Fast Convergence for Stochastic and Distribute...  2018
#
#                                                 keywords
# 11196  [coordinate, optimization, important, computat...
# 14699  [constraint, constraint, attachment, constitue...
# 27283  [supervised, detection, challenging, simultane...
# 699    [significance, ubiquitous, throughout, recogni...
# 4456   [approaches, potential, automated, detection, ...
# ...                                                  ...
# 33667  [evolutionary, artificial, evolutionary, biolo...
# 23656  [important, maintaining, production, manufactu...
# 34214  [communicating, information, opinionated, info...
# 21818  [dimensional, prevalent, biomedical, chemometr...
# 7774   [supervised, techniques, particularly, dimensi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11196    [coordinate, optimization, important, computat...
# 14699    [constraint, constraint, attachment, constitue...
# 27283    [supervised, detection, challenging, simultane...
# 699      [significance, ubiquitous, throughout, recogni...
# 4456     [approaches, potential, automated, detection, ...
#                                ...
# 6180     [algorithms, minimization, empirical, performa...
# 21581    [associative, candidates, generalization, prin...
# 12541    [successes, reinforcement, development, contro...
# 4908     [reinforcement, partially, observable, environ...
# 14108    [diagnosis, mechanical, challenge, development...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8729 words.
# Out of those 4605 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="de3f2ad5-2f96-4fc1-95a8-4de42e3a2c01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de3f2ad5-2f96-4fc1-95a8-4de42e3a2c01")) {                    Plotly.newPlot(                        "de3f2ad5-2f96-4fc1-95a8-4de42e3a2c01",                        [{"x":["modifications","dimensions","algorithm","convergence","outstanding","optimization","structure","initialization","estimation","frameworks","empirical","guaranteeing","challenge","dimensional","framework","guarantees","significant","algorithmic","algorithms","development","parameter","experiments","theoretical","computational","classical","coordinate","important","nonconvex","particularly","performance","properties","statistical","numerical","constraint","annotated","implications","documents","performed","attachment","constituents","structures","qualitative","respected","approaches","annotators","violations","misconceptions","different","interpretation","structural","discourse","ambiguous","curriculum","challenging","knowledge","potential","detection","intuitively","gradually","comprehensively","technique","mechanism","experimental","simultaneously","simulating","procedure","demonstrate","attractive","supervision","locations","attention","successfully","supervised","detectors","selective","challenges","psychophysical","deepening","throughout","inversion","mechanisms","fundamental","parsimonious","empirically","composite","principle","understanding","interaction","computations","behavioral","understood","ubiquitous","significance","phenomena","processing","relatively","correspond","furthermore","characteristic","underlying","recognition","characteristics","disparate","exploring","architectures","typically","comparison","recurrent","competing","reinforcement","indicating","convolutional","informing","advantages","pulmonary","promising","containing","methodologies","architecture","automated","propagated","classification","available","annotation","historical","radiographs","difficult","radiological","estimated","associated","accordingly","localisation","corresponding","reasoning","efficient","elicitation","practical","consequence","probability","observation","probabilistic","parameters","approximated","applications","substantially","conditional","treatment","information","physicians","sequential","decisions","population","favorable","estimating","illustrate","depression","corresponds","addresses","specifically","presented","strategies","previously","observations","recognize","definition","exploiting","sensitive","enhancing","classifying","represented","diagnosis","surprisingly","adaptation","significantly","introduce","including","distribution","initially","segmentation","proposing","baselines","simulated","condition","alignment","techniques","adversarial","outperforms","synthetic","environments","geographic","successful","constrained","generalization","prediction","unsupervised","aggregates","concentration","effective","independently","encounter"],"y":[16,43,793,114,9,320,314,25,211,24,145,1,178,191,530,59,226,44,606,140,126,624,158,301,97,20,395,12,89,886,223,161,84,89,75,29,54,115,2,5,122,59,2,435,13,4,3,762,51,66,22,27,9,263,353,156,370,15,11,6,248,97,375,99,6,127,595,20,47,39,157,91,194,42,20,120,3,2,23,10,46,94,5,75,11,57,162,71,29,14,28,12,15,24,285,56,14,175,22,120,379,94,5,42,116,97,147,160,22,119,15,384,1,94,5,112,62,20,250,113,3,521,294,66,17,2,151,3,47,122,13,5,117,133,410,11,136,24,182,71,161,260,21,453,37,83,35,713,7,83,61,51,7,66,67,2,29,43,173,174,108,94,83,52,39,88,63,23,29,95,53,30,75,267,339,300,196,28,224,16,61,62,50,46,389,105,251,118,86,9,75,64,106,223,147,10,9,223,42,5],"type":"bar"},{"x":["modifications","dimensions","algorithm","convergence","outstanding","optimiz ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4605,), (4605, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7883333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Real</span> <span style=''>time</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.6371490280777539);'>recognition</span> <span style=''>using</span> <span style=''>adaboost</span> <span style=''>improved</span> <span style=''>fast</span> <span style=''>PCA</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5694444444444444);'>automated</span> <span style=''>system</span> <span style=''>for</span> <span style=''>human</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.6371490280777539);'>recognition</span> <span style=''>in</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.5824175824175823);'>background</span> <span style=''>world</span> <span style=''>for</span> <span style=''>a</span> <span style=''>large</span> <span style=''>homemade</span> <span style=''>dataset</span> <span style=''>of</span> <span style=''>persons</span> <span style=''>face</span> <span style=''>The</span> <span style=''>task</span> <span style=''>is</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>as</span> <span style=''>the</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.5824175824175823);'>background</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>subtraction</span> <span style=''>in</span> <span style=''>an</span> <span style=''>image</span> <span style=''>is</span> <span style=''>still</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.30882352941176466);'>challenge</span> <span style=''>Addition</span> <span style=''>to</span> <span style=''>this</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>huge</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style=''>in</span> <span style=''>human</span> <span style=''>face</span> <span style=''>image</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>size</span> <span style=''>pose</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expression</span> <span style=''>The</span> <span style=''>system</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>collapses</span> <span style=''>most</span> <span style=''>of</span> <span style=''>this</span> <span style=''>variance</span> <span style=''>To</span> <span style=''>detect</span> <span style=''>real</span> <span style=''>time</span> <span style=''>human</span> <span style=''>face</span> <span style=''>AdaBoost</span> <span style=''>with</span> <span style=''>Haar</span> <span style=''>cascade</span> <span style=''>is</span> <span style=''>used</span> <span style=''>and</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>fast</span> <span style=''>PCA</span> <span style=''>and</span> <span style=''>LDA</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>recognize</span> <span style=''>the</span> <span style=''>faces</span> <span style=''>detected</span> <span style=''>The</span> <span style=''>matched</span> <span style=''>face</span> <span style=''>is</span> <span style=''>then</span> <span style=''>used</span> <span style=''>to</span> <span style=''>mark</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>attendance</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>laboratory</span> <span style=''>in</span> <span style=''>our</span> <span style=''>case< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>mixtures</span> <span style=''>of</span> <span style=''>spatial</span> <span style=''>spline</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regressions</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>relates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>for</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style=''>surfaces</span> <span style=''>We</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>spatial</span> <span style=''>spline</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>with</span> <span style=''>mixed</span> <span style=''>effects</span> <span style=''>(BSSR)</span> <span style=''>for</span> <span style=''>modeling</span> <span style=''>spatial</span> <span style=''>function</span> <span style=''>data</span> <span style=''>The</span> <span style=''>BSSR</span> <span style=''>model</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Nodal</span> <span style=''>basis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>for</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodates</span> <span style=''>both</span> <span style=''>common</span> <span style=''>mean</span> <span style=''>behavior</span> <span style=''>for</span> <span style=''>the</span> <span style=''>data</span> <span style=''>through</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>effects</span> <span style=''>part</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variability</span> <span style=''>inter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individuals</span> <span style=''>thanks</span> <span style=''>to</span> <span style=''>a</span> <span style=''>random</span> <span style=''>effects</span> <span style=''>part</span> <span style=''>Then</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>populations</span> <span style=''>of</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>issued</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style=''>groups</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrate</span> <span style=''>the</span> <span style=''>BSSR</span> <span style=''>model</span> <span style=''>into</span> <span style=''>a</span> <span style=''>mixture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>spatial</span> <span style=''>spline</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regressions</span> <span style=''>with</span> <span style=''>mixed</span> <span style=''>effects</span> <span style=''>(BMSSR)</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Near</span> <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>Sketching</span> <span style=''>of</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.43685300207039335);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(255, 0, 0, 0.43685300207039335);'>regression</span> <span style=''>problem</span> <span style=''>beginalign</span> <span style=''>min</span> <span style=''>Theta</span> <span style=''>in</span> <span style=''>mathcalS</span> <span style=''>odot</span> <span style=''>DR</span> <span style=''>|ATheta</span> <span style=''>b|</span> <span style=''>2</span> <span style=''>endalign</span> <span style=''>where</span> <span style=''>mathcalS</span> <span style=''>odot</span> <span style=''>DR</span> <span style=''>is</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>Theta</span> <span style=''>for</span> <span style=''>which</span> <span style=''>Theta</span> <span style=''>sum</span> <span style=''>r1R</span> <span style=''>theta</span> <span style=''>1(r)</span> <span style=''>circ</span> <span style=''>cdots</span> <span style=''>circ</span> <span style=''>theta</span> <span style=''>D(r)</span> <span style=''>for</span> <span style=''>vectors</span> <span style=''>theta</span> <span style=''>d(r)</span> <span style=''>in</span> <span style=''>mathbbRp</span> <span style=''>d</span> <span style=''>for</span> <span style=''>all</span> <span style=''>r</span> <span style=''>in</span> <span style=''>R</span> <span style=''>and</span> <span style=''>d</span> <span style=''>in</span> <span style=''>D</span> <span style=''>and</span> <span style=''>circ</span> <span style=''>denotes</span> <span style=''>the</span> <span style=''>outer</span> <span style=''>product</span> <span style=''>of</span> <span style=''>vectors</span> <span style=''>That</span> <span style=''>is</span> <span style=''>Theta</span> <span style=''>is</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.32389380530973444);'>dimensional</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style=''>This</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>Theta</span> <span style=''>is</span> <span style=''>only</span> <span style=''>R</span> <span style=''>cdot</span> <span style=''>sum</span> <span style=''>d1D</span> <span style=''>p</span> <span style=''>d</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>smaller</span> <span style=''>than</span> <span style=''>the</span> <span style=''>prod</span> <span style=''>d1D</span> <span style=''>p</span> <span style=''>d</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>ordinary</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(255, 0, 0, 0.43685300207039335);'>regression</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>above</span> <span style=''>CP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>model</span> <span style=''>of</span> <span style=''>tensors</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifier</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Calibration</span> <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>approach</span> <br/><br/><span style=''>Accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibration</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>models</span> <span style=''>learned</span> <span style=''>is</span> <span style=''>critical</span> <span style=''>for</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>and</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>tasks</span> <span style=''>There</span> <span style=''>are</span> <span style=''>two</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categories</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>building</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibrated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>One</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>that</span> <span style=''>are</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibrated</span> <span style=''>ab</span> <span style=''>initio</span> <span style=''>The</span> <span style=''>other</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>use</span> <span style=''>some</span> <span style=''>post</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transforming</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>to</span> <span style=''>be</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibrated</span> <span style=''>as</span> <span style=''>for</span> <span style=''>example</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>histogram</span> <span style=''>binning</span> <span style=''>Platt</span> <span style=''>scaling</span> <span style=''>and</span> <span style=''>isotonic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>One</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style=''>post</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>any</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>model</span> <span style=''>that</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>using</span> <span style=''>any</span> <span style=''>machine</span> <span style=''>learnin ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1323685139428168)
# 	knowledge (0.12460289445817155)
# 	processing (0.10060007059654077)
# 	architecture (0.08824567596187786)
# 	segmentation (0.07906812566184257)
# 	information (0.2516766678432757)
# 	detection (0.13060360042357924)
# 	different (0.26897282033180375)
# 	recognition (0.13378044475820686)
# 	convolutional (0.1355453582774444)
#
# Some Statistics words are:
# 	variables (0.1367564819522115)
# 	statistical (0.15048296898830707)
# 	stochastic (0.1418403660396543)
# 	theoretical (0.15912557193695984)
# 	estimation (0.18047788510421964)
# 	distribution (0.1809862735129639)
# 	algorithm (0.39705134722928315)
# 	dimensional (0.19013726487036095)
# 	regression (0.17641077783426537)
# 	inference (0.19827147941026946)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9b5b8463-c368-46b2-83ce-6f94ae2dfa11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b5b8463-c368-46b2-83ce-6f94ae2dfa11")) {                    Plotly.newPlot(                        "9b5b8463-c368-46b2-83ce-6f94ae2dfa11",                        [{"x":["modifications","dimensions","algorithm","convergence","outstanding","optimization","structure","initialization","estimation","frameworks","empirical","guaranteeing","challenge","dimensional","framework","guarantees","significant","algorithmic","algorithms","development","parameter","experiments","theoretical","computational","classical","coordinate","important","nonconvex","particularly","performance","properties","statistical","numerical","constraint","annotated","implications","documents","performed","attachment","constituents","structures","qualitative","respected","approaches","annotators","violations","misconceptions","different","interpretation","structural","discourse","ambiguous","curriculum","challenging","knowledge","potential","detection","intuitively","gradually","comprehensively","technique","mechanism","experimental","simultaneously","simulating","procedure","demonstrate","attractive","supervision","locations","attention","successfully","supervised","detectors","selective","challenges","psychophysical","deepening","throughout","inversion","mechanisms","fundamental","parsimonious","empirically","composite","principle","understanding","interaction","computations","behavioral","understood","ubiquitous","significance","phenomena","processing","relatively","correspond","furthermore","characteristic","underlying","recognition","characteristics","disparate","exploring","architectures","typically","comparison","recurrent","competing","reinforcement","indicating","convolutional","informing","advantages","pulmonary","promising","containing","methodologies","architecture","automated","propagated","classification","available","annotation","historical","radiographs","difficult","radiological","estimated","associated","accordingly","localisation","corresponding","reasoning","efficient","elicitation","practical","consequence","probability","observation","probabilistic","parameters","approximated","applications","substantially","conditional","treatment","information","physicians","sequential","decisions","population","favorable","estimating","illustrate","depression","corresponds","addresses","specifically","presented","strategies","previously","observations","recognize","definition","exploiting","sensitive","enhancing","classifying","represented","diagnosis","surprisingly","adaptation","significantly","introduce","including","distribution","initially","segmentation","proposing","baselines","simulated","condition","alignment","techniques","adversarial","outperforms","synthetic","environments","geographic","successful","constrained","generalization","prediction","unsupervised","aggregates","concentration","effective","independently","encounter","inference","posterior","geometric","selection","probabilities","contamination","processed","equations","computationally","unsuitable","nonlinear","formulates","embedding","expensive","individual","stochastic","reduction","functions","expectation","composition","effectiveness","objective","approximate","elimination","graphical","symmetric","approximations","computing","transformations","partition","intractable","variational","approximation","keypoints","conclusion","difficulty","regression","comprehensive","demonstrates","investigation","influences","clustering","identifying","unlabelled","justification","correctly","subspaces","guarantee","considers","complexity","utilizing","separates","automatically","hierarchical","consuming","integrated","r ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	semiparametric
# 	reinterpret
# 	reparametrizations
# 	counteracts
# 	inspecting
# 	hermitian
# 	standardized
# 	nonconjugate
# 	adjustable
# 	calculable
# 	confounders
# 	snapshots
# 	infinitesimal
# 	jackknife
# 	correlational
# 	detectability
# 	uncollapsed
# 	trilinear
# 	strikingly
# 	perturbing
# Some words which never appear in Statistics papers:
# 	misconceptions
# 	discourse
# 	comprehensively
# 	psychophysical
# 	deepening
# 	prioritized
# 	whatsoever
# 	axiomatization
# 	reconciling
# 	ukrainian
# 	concatenating
# 	localizing
# 	quadrilateral
# 	abduction
# 	multilevel
# 	trafficking
# 	compensation
# 	sustainable
# 	backpropagated
# 	personalize

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0362835888872024e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7383333333333333
